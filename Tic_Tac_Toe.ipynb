# %%
play = 1
board = [11,12,13,21,22,23,31,32,33]
print(board[:3])
print(board[3:6])
print(board[6:])

num = 5
for x in range(num):
  play1_move = int(input("PLAYER 1 type the number that corresponds with your move: "))
  if play1_move == 11:
    i = board.index(play1_move)
    board = board[:i]+["x"]+board[i+1:]
    print(board[:3])
    print(board[3:6])
    print(board[6:])
  elif play1_move == 12:
    i = board.index(play1_move)
    board = board[:i]+["x"]+board[i+1:]
    print(board[:3])
    print(board[3:6])
    print(board[6:])
  elif play1_move == 13:
    i = board.index(play1_move)
    board = board[:i]+["x"]+board[i+1:]
    print(board[:3])
    print(board[3:6])
    print(board[6:])
  elif play1_move == 21:
    i = board.index(play1_move)
    board = board[:i]+["x"]+board[i+1:]
    print(board[:3])
    print(board[3:6])
    print(board[6:])
  elif play1_move == 22:
    i = board.index(play1_move)
    board = board[:i]+["x"]+board[i+1:]
    print(board[:3])
    print(board[3:6])
    print(board[6:])
  elif play1_move == 23:
    i = board.index(play1_move)
    board = board[:i]+["x"]+board[i+1:]
    print(board[:3])
    print(board[3:6])
    print(board[6:])
  elif play1_move == 31:
    i = board.index(play1_move)
    board = board[:i]+["x"]+board[i+1:]
    print(board[:3])
    print(board[3:6])
    print(board[6:])
  elif play1_move == 32:
    i = board.index(play1_move)
    board = board[:i]+["x"]+board[i+1:]
    print(board[:3])
    print(board[3:6])
    print(board[6:])
  elif play1_move == 33:
    i = board.index(play1_move)
    board = board[:i]+["x"]
    print(board[:3])
    print(board[3:6])
    print(board[6:])
  else:
    print('choose a valid number')
  
  if board[:3] == ['x','x','x']:
    print("PLAYER 1 WINS")
    break
  if board[3:6] == ['x','x','x']:
    print("PLAYER 1 WINS")
    break
  if board[6:] == ['x','x','x']:
    print("PLAYER 1 WINS")
    break
  if board[0] == 'x' and board[3] == 'x' and board[6] == 'x':
    print("PLAYER 1 WINS")
    break
  if board[1] == 'x' and board[4] == 'x' and board[7] == 'x':
    print("PLAYER 1 WINS")
    break
  if board[2] == 'x' and board[5] == 'x' and board[8] == 'x':
    print("PLAYER 1 WINS")
    break
  if board[0] == 'x' and board[4] == 'x' and board[-1] == 'x':
    print("PLAYER 1 WINS")
    break
  if board[2] == 'x' and board[4] == 'x' and board[6] == 'x':
    print("PLAYER 1 WINS")
    break
 
  if x == 4:
    print('DRAW')
    break

  play2_move = int(input("PLAYER 2 type the number that corresponds with your move: "))
  if play2_move == 11:
    i = board.index(play2_move)
    board = board[:i]+["o"]+board[i+1:]
    print(board[:3])
    print(board[3:6])
    print(board[6:])
  elif play2_move == 12:
    i = board.index(play2_move)
    board = board[:i]+["o"]+board[i+1:]
    print(board[:3])
    print(board[3:6])
    print(board[6:])
  elif play2_move == 13:
    i = board.index(play2_move)
    board = board[:i]+["o"]+board[i+1:]
    print(board[:3])
    print(board[3:6])
    print(board[6:])
  elif play2_move == 21:
    i = board.index(play2_move)
    board = board[:i]+["o"]+board[i+1:]
    print(board[:3])
    print(board[3:6])
    print(board[6:])
  elif play2_move == 22:
    i = board.index(play2_move)
    board = board[:i]+["o"]+board[i+1:]
    print(board[:3])
    print(board[3:6])
    print(board[6:])
  elif play2_move == 23:
    i = board.index(play2_move)
    board = board[:i]+["o"]+board[i+1:]
    print(board[:3])
    print(board[3:6])
    print(board[6:])
  elif play2_move == 31:
    i = board.index(play2_move)
    board = board[:i]+["o"]+board[i+1:]
    print(board[:3])
    print(board[3:6])
    print(board[6:])
  elif play2_move == 32:
    i = board.index(play2_move)
    board = board[:i]+["o"]+board[i+1:]
    print(board[:3])
    print(board[3:6])
    print(board[6:])
  elif play2_move == 33:
    i = board.index(play2_move)
    board = board[:i]+["o"]
    print(board[:3])
    print(board[3:6])
    print(board[6:])
    
  else:
    print('choose a valid number')

  if board[:3] == ['o','o','o']:
    print("PLAYER 2 WINS")
    break
  if board[3:6] == ['o','o','o']:
    print("PLAYER 2 WINS")
    break
  if board[6:] == ['o','o','o']:
    print("PLAYER 2 WINS")
    break
  if board[0] == 'o' and board[3] == 'o' and board[6] == 'o':
    print("PLAYER 2 WINS")
    break
  if board[1] == 'o' and board[4] == 'o' and board[7] == 'o':
    print("PLAYER 2 WINS")
    break
  if board[2] == 'o' and board[5] == 'o' and board[8] == 'o':
    print("PLAYER 2 WINS")
    break
  if board[0] == 'o' and board[4] == 'o' and board[-1] == 'o':
    print("PLAYER 2 WINS")
    break
  if board[2] == 'o' and board[4] == 'o' and board[6] == 'o':
    print("PLAYER 2 WINS")
    break
  
    
print("game ended")
# Out:
# [11, 12, 13]
# [21, 22, 23]
# [31, 32, 33]
# PLAYER 1 type the number that corresponds with your move: 11
# ['x', 12, 13]
# [21, 22, 23]
# [31, 32, 33]
# PLAYER 2 type the number that corresponds with your move: 12
# ['x', 'o', 13]
# [21, 22, 23]
# [31, 32, 33]
# PLAYER 1 type the number that corresponds with your move: 13
# ['x', 'o', 'x']
# [21, 22, 23]
# [31, 32, 33]
# PLAYER 2 type the number that corresponds with your move: 22
# ['x', 'o', 'x']
# [21, 'o', 23]
# [31, 32, 33]
# PLAYER 1 type the number that corresponds with your move: 21
# ['x', 'o', 'x']
# ['x', 'o', 23]
# [31, 32, 33]
# PLAYER 2 type the number that corresponds with your move: 23
# ['x', 'o', 'x']
# ['x', 'o', 'o']
# [31, 32, 33]
# PLAYER 1 type the number that corresponds with your move: 32
# ['x', 'o', 'x']
# ['x', 'o', 'o']
# [31, 'x', 33]
# PLAYER 2 type the number that corresponds with your move: 31
# ['x', 'o', 'x']
# ['x', 'o', 'o']
# ['o', 'x', 33]
# ...

# %%
i=1
list = ['x','x','x',1,2]
if i == 1:
  print('no')
elif list[:3] == ['x','x','x']:
  print("yes")
  break
# Out:
#   File "<ipython-input-128-5eaa9fe84ad8>", line 7
#     break
#     ^
# SyntaxError: 'break' outside loop
